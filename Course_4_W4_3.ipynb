# %% [markdown]
# <a href="https://colab.research.google.com/github/cysorianoc/IBM_Data_Science/blob/main/Course_4_W4_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>
#
# # Practice Lab: Selecting data in a Dataframe
#
# Estimated time needed: **30** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Use Pandas Library to create DataFrame and Series
# *   Locate data in the DataFrame using <code>loc()</code> and <code>iloc()</code> functions
# *   Use slicing

# %% [markdown]
# ### Exercise 1: Pandas: DataFrame and Series
#
# **Pandas** is a popular library for data analysis built on top of the Python programming language. Pandas generally provide two data structures for manipulating data, They are:
#
# * DataFrame
# * Series
#
# A **DataFrame** is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns.
#
# * A Pandas DataFrame will be created by loading the datasets from existing storage.
# * Storage can be SQL Database, CSV file, Excel file, etc.
# * It can also be created from the lists, dictionaries, and from a list of dictionaries.
#
# **Series** represents a one-dimensional array of indexed data.
# It has two main components :
# 1. An array of actual data.
# 2. An associated array of indexes or data labels.
#
# The index is used to access individual data values. You can also get a column of a dataframe as a **Series**. You can think of a Pandas series as a 1-D dataframe.

# %%
# let us import the Pandas Library
import pandas as pd

# %% [markdown]
# Once you’ve imported pandas, you can then use the functions built in it to create and analyze data.

# %% [markdown]
# **In this practice lab, we will learn how to create a DataFrame out of a dictionary.**

# %% [markdown]
# Let us consider a dictionary 'x' with keys and values as shown below.
#
# We then create a dataframe from the dictionary using the function pd.DataFrame(dict)

# %%
#Define a dictionary 'x'

x = {'Name': ['Rose','John', 'Jane', 'Mary'], 'ID': [1, 2, 3, 4], 'Department': ['Architect Group', 'Software Group', 'Design Team', 'Infrastructure'],
      'Salary':[100000, 80000, 50000, 60000]}

#casting the dictionary to a DataFrame
df = pd.DataFrame(x)

#display the result df
df
# Out:
#    Name  ID       Department  Salary
# 0  Rose   1  Architect Group  100000
# 1  John   2   Software Group   80000
# 2  Jane   3      Design Team   50000
# 3  Mary   4   Infrastructure   60000

# %% [markdown]
# We can see the direct correspondence between the table. The keys correspond to the column labels and the values or lists correspond to the rows.

# %% [markdown]
# #### Column Selection:
#
# To select a column in Pandas DataFrame, we can either access the columns by calling them by their columns name.
#
# Let's Retrieve the data present in the <code>ID</code> column.

# %%
#Retrieving the "ID" column and assigning it to a variable x
x = df[['ID']]
x
# Out:
#    ID
# 0   1
# 1   2
# 2   3
# 3   4

# %% [markdown]
# Let's use the <code>type()</code> function and check the type of the variable.

# %%
#check the type of x
type(x)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# The output shows us that the type of the variable is a DataFrame object.

# %% [markdown]
# #### Access to multiple columns
#
# Let us retrieve the data for <code>Department</code>, <code>Salary</code> and <code>ID</code> columns

# %%
#Retrieving the Department, Salary and ID columns and assigning it to a variable z

z = df[['Department','Salary','ID']]
z
# Out:
#         Department  Salary  ID
# 0  Architect Group  100000   1
# 1   Software Group   80000   2
# 2      Design Team   50000   3
# 3   Infrastructure   60000   4

# %% [markdown]
# ### Try it yourself

# %% [markdown]
# ##### Problem 1: Create a dataframe to display the result as below:

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/images/Student_data.png" width="300" alt="Student Data">
# </center>

# %%
#Define a dictionary 'y'

y = {'Student': ['David','Samuel', 'Terry', 'Evan'], 'Age': [27, 24, 22, 32], 'Country': ['UK', 'Canada', 'China', 'USA'],
      'Course':['Python','Data Structures' , 'Machine Learning', 'Web Development'], 'Marks':[85,72,89,76]}

#casting the dictionary to a DataFrame
df2 = pd.DataFrame(y)

#display the result df
df2
# Out:
#   Student  Age Country            Course  Marks
# 0   David   27      UK            Python     85
# 1  Samuel   24  Canada   Data Structures     72
# 2   Terry   22   China  Machine Learning     89
# 3    Evan   32     USA   Web Development     76

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# a = {'Student':['David', 'Samuel', 'Terry', 'Evan'],
#      'Age':['27', '24', '22', '32'],
#      'Country':['UK', 'Canada', 'China', 'USA'],
#      'Course':['Python','Data Structures','Machine Learning','Web Development'],
#      'Marks':['85','72','89','76']}
# df1 = pd.DataFrame(a)
# df1
#
# ```
#
# </details>

# %% [markdown]
# ##### Problem 2: Retrieve the Marks column and assign it to a variable b

# %%
b=df2[['Marks']]
b
# Out:
#    Marks
# 0     85
# 1     72
# 2     89
# 3     76

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# b = df1[['Marks']]
# b
#
# ```
#
# </details>

# %% [markdown]
# ##### Problem 3: Retrieve the Country and Course columns and assign it to a variable c

# %%
c=df2[['Country','Course']]
c
# Out:
#   Country            Course
# 0      UK            Python
# 1  Canada   Data Structures
# 2   China  Machine Learning
# 3     USA   Web Development

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# c = df1[['Country','Course']]
# c
#
# ```
#
# </details>

# %% [markdown]
# #### To view the column as a series, just use one bracket:

# %%
# Get the Student column as a series Object

x = df2['Student']
x
# Out:
# 0     David
# 1    Samuel
# 2     Terry
# 3      Evan
# Name: Student, dtype: object

# %%
#check the type of x
type(x)
# Out:
# pandas.core.series.Series

# %% [markdown]
# The output shows us that the type of the variable is a Series object.

# %% [markdown]
# ### Exercise 2: <code>loc()</code> and <code>iloc()</code> functions
#
# <code>loc()</code> is a label-based data selecting method which means that we have to pass the name of the row or column that we want to select. This method includes the last element of the range passed in it.
#
# Simple syntax for your understanding:
#
#  - loc[row_label, column_label]
#
# <code>iloc()</code> is an indexed-based selecting method which means that we have to pass an integer index in the method to select a specific row/column. This method does not include the last element of the range passed in it.
#
# Simple syntax for your understanding:
#
#  - iloc[row_index, column_index]
#
# <h4 id="data">Let us see some examples on the same.</h4>

# %%
# Access the value on the first row and the first column

df2.iloc[0, 0]
# Out:
# 'David'

# %%
# Access the value on the first row and the third column

df2.iloc[0,2]
# Out:
# 'UK'

# %%
# Access the column using the name

df2.loc[0:2, 'Course']
# Out:
# 0              Python
# 1     Data Structures
# 2    Machine Learning
# Name: Course, dtype: object

# %% [markdown]
# Let us create a new dataframe called 'df3![1717117894725.jfif](data:image/jpeg;base64,...)' and assign 'df' to it. Now, let us set the "Name" column as an index column using the method set_index().

# %%
df3=df
df3=df3.set_index("Name")

# %%
#To display the first 5 rows of new dataframe
df3.head()
# Out:
#       ID       Department  Salary
# Name
# Rose   1  Architect Group  100000
# John   2   Software Group   80000
# Jane   3      Design Team   50000
# Mary   4   Infrastructure   60000

# %%
#Now, let us access the column using the name
df3.loc['Jane', 'Salary']
# Out:
# 50000

# %% [markdown]
# ### Try it yourself

# %% [markdown]
# Use the <code>loc()</code> function,to get the Department of Jane in the newly created dataframe df3.

# %%
df3.loc['Jane', 'Department']
# Out:
# 'Design Team'

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df2.loc['Jane', 'Department']
#
# ```
#
# </details>

# %% [markdown]
# Use the <code>iloc()</code> function to get the Salary of Mary in the newly created dataframe df3.

# %%
df3.iloc[3,2]
# remember, first rows, then columns
# Out:
# 60000

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df2.iloc[3,2]
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3: Slicing
#
# Slicing uses the [] operator to select a set of rows and/or columns from a DataFrame.
#
# To slice out a set of rows, you use this syntax: data[start:stop],
#
# here the start represents the index from where to consider, and stop represents the index one step BEYOND the row you want to select. You can perform slicing using both the index and the name of the column.
#
# > NOTE: When slicing in pandas, the start bound is included in the output.
#
# So if you want to select rows 0, 1, and 2 your code would look like this: df.iloc[0:3].
#
# It means you are telling Python to start at index 0 and select rows 0, 1, 2 up to but not including 3.
#
# > NOTE: Labels must be found in the DataFrame or you will get a KeyError.
#
# Indexing by labels(i.e. using <code>loc()</code>) differs from indexing by integers (i.e. using <code>iloc()</code>). With <code>loc()</code>, both the start bound and the stop bound are inclusive. When using <code>loc()</code>, integers can be used, but the integers refer to the index label and not the position.
#
# For example, using <code>loc()</code> and select 1:4 will get a different result than using <code>iloc()</code> to select rows 1:4.
#
# <h4 id="data">We can also select a specific data value using a row and column location within the DataFrame and iloc indexing.

# %%
x = {'Name': ['Rose','John', 'Jane', 'Mary'], 'ID': [1, 2, 3, 4], 'Department': ['Architect Group', 'Software Group', 'Design Team', 'Infrastructure'],
      'Salary':[100000, 80000, 50000, 60000]}

#casting the dictionary to a DataFrame
df = pd.DataFrame(x)

#display the result df
df
# Out:
#    Name  ID       Department  Salary
# 0  Rose   1  Architect Group  100000
# 1  John   2   Software Group   80000
# 2  Jane   3      Design Team   50000
# 3  Mary   4   Infrastructure   60000

# %%
# let us do the slicing using old dataframe df

df.iloc[0:2, 0:3]

# so as you can see it takes the n-1 index when using iloc()
# Out:
#    Name  ID       Department
# 0  Rose   1  Architect Group
# 1  John   2   Software Group

# %%
#let us do the slicing using loc() function on old dataframe df where index column is having labels as 0,1,2
df.loc[0:2,'ID':'Department']
# Out:
#    ID       Department
# 0   1  Architect Group
# 1   2   Software Group
# 2   3      Design Team

# %%
#let us do the slicing using loc() function on new dataframe df3 where index column is Name having labels: Rose, John and Jane
df3.loc['Rose':'Jane', 'ID':'Department']
# Out:
#       ID       Department
# Name
# Rose   1  Architect Group
# John   2   Software Group
# Jane   3      Design Team

# %% [markdown]
# <h2 id="quiz">Try it yourself</h2>

# %% [markdown]
# using <code>loc()</code> function, do slicing on old dataframe df to retrieve the Name, ID and department of index columns going from 2 to 3

# %%
x = {'Name': ['Rose','John', 'Jane', 'Mary'], 'ID': [1, 2, 3, 4], 'Department': ['Architect Group', 'Software Group', 'Design Team', 'Infrastructure'],
      'Salary':[100000, 80000, 50000, 60000]}

#casting the dictionary to a DataFrame
df = pd.DataFrame(x)

#display the result df
df
# Out:
#    Name  ID       Department  Salary
# 0  Rose   1  Architect Group  100000
# 1  John   2   Software Group   80000
# 2  Jane   3      Design Team   50000
# 3  Mary   4   Infrastructure   60000

# %%
df.loc[2:3,'Name':'Department']
# Out:
#    Name  ID      Department
# 2  Jane   3     Design Team
# 3  Mary   4  Infrastructure

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df.loc[2:3,'Name':'Department']
#
# ```
#
# </details>

# %% [markdown]
# <h3 id="quiz">Congratulations, you have completed this lesson and the practice lab on Pandas</h3>

# %% [markdown]
# ## Author(s):
#
# [Appalabhaktula Hema](https://www.linkedin.com/in/hema-a-39002b128/)
#
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By          | Change Description                 |
# | ----------------- | ------- | ------------------- | ---------------------------------- |
# | 2022-03-31        | 0.1     | Appalabhaktula Hema | Created initial version            |
#
# <hr/>
#
# ## <h3 align="center"> © IBM Corporation 2022. All rights reserved. <h3/>

# %% [markdown]
# Now an example with some data. Consisting on a T-bar test to estimate the undrained shear strength of a clayey soil profile during a centrifuge test.

# %%
# Create a dataframe by readeing the .csv file

t_bar=pd.read_csv('SW_01_TBAR6_MO.csv')
t_bar.head()
# Out:
#    time    F_Tbar    z_Tbar
# 0  0.00  3.833784  0.231421
# 1  0.01  3.809658  0.241216
# 2  0.02  3.801616  0.254784
# 3  0.03  3.838901  0.265341
# 4  0.04  3.853523  0.272889

# %% [markdown]
# The next stage is to plot the relationship between the measured force and the depth of the test. As we can see, the values do not start from zero, so we need to apply an offset.

# %%
# @title F_Tbar vs z_Tbar

from matplotlib import pyplot as plt
t_bar.plot(kind='scatter', x='F_Tbar', y='z_Tbar', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# %% [markdown]
# This is a 'manual' form basically by changing the offset value in the depth and force columns. Additionally, the force of contact with the soil during the push of the T bar is initially negative due to the calibration of the load cell. So I reversed it. The other part of the plot represents the pullout of the T bar.

# %%
from matplotlib import pyplot as plt

# Assuming t_bar is your DataFrame and you have already imported it

# Check if the offset has already been applied
if 'offset_applied' not in t_bar.columns:
    # Subtract the offset value of F_Tbar from all F_Tbar values
    t_bar['F_Tbar'] = (t_bar['F_Tbar'] - 4) * -1

    # Subtract the offset value of z_Tbar from all z_Tbar values
    t_bar['z_Tbar'] = t_bar['z_Tbar'] + 30

    # Mark that the offset has been applied
    t_bar['offset_applied'] = True

# Create the scatter plot
t_bar.plot(kind='scatter', x='F_Tbar', y='z_Tbar', s=32, alpha=.8)

# Hide the top and right spines
plt.gca().spines[['top', 'right']].set_visible(False)

# Add and customize grid lines
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Set the x-axis limit to show only positive values
plt.xlim(left=0)

# Display the plot
plt.show()

# %% [markdown]
# Here I tried to "automatize" at least for the force the offset by taking the average of the first 5 values of the force column. For the depth it still "manual" to find the contact point of the T bar with the clay. Some othe edits were added to the plot to show finally the load cell force with depth duting the push of the T bar.

# %%
from matplotlib import pyplot as plt

# Assuming t_bar is your DataFrame and you have already imported it

# Check if the offset has already been applied
if 'offset_applied' not in t_bar.columns:
    # Calculate the average of the first five values for F_Tbar and z_Tbar
    F_Tbar_offset = t_bar['F_Tbar'].iloc[:5].mean()
    z_Tbar_offset = 30 # this value was to move the depth axis to start at zero

    # Subtract the calculated offset values
    t_bar['F_Tbar'] = (t_bar['F_Tbar'] - F_Tbar_offset)*-1
    t_bar['z_Tbar'] = t_bar['z_Tbar'] - z_Tbar_offset

    # Mark that the offset has been applied
    t_bar['offset_applied'] = True

# Create the scatter plot
t_bar.plot(kind='scatter', x='F_Tbar', y='z_Tbar', s=32, alpha=.8)

# Hide the top and right spines
plt.gca().spines[['top', 'right']].set_visible(False)

# Add and customize grid lines
plt.grid(True, which='both', linestyle='--', linewidth=0.5, color='gray', alpha=0.7)

# Set the x-axis limit to show only positive values
plt.xlim(left=0)
plt.ylim(top=0)
plt.ylim(bottom=-250)
# Display the plot
plt.show()

# %% [markdown]
# This is an example of the T bar concept
#
# [https://www.researchgate.net/publication/286735207_Geotechnics_offshore_Australia_-_Beyond_traditional_soil_mechanics](https://)
#
#
# <img title="example of a tbar" alt="Alt text" src="https://www.researchgate.net/profile/David-White-38/publication/286735207/figure/fig1/AS:308733436547074@1450619195872/Cone-T-bar-and-ball-penetrometers_W640.jpg">
