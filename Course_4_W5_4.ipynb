# %% [markdown]
# <a href="https://colab.research.google.com/github/cysorianoc/IBM_Data_Science/blob/main/Course_4_W5_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Hands-on Lab: API Examples
# ## Random User and Fruityvice API Examples
#
#
# Estimated time needed: **30** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruityvice API, using `requests` Python library
# *   Load and use Open-Joke-API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#  *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more
#      productive.
#  *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#      independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#  *   **Security**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruityvice application. The Fruityvice API web service which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The web service is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation) page.

# %% [markdown]
# ## **Get Methods**
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5066 sha256=4f46a3c901079a1c1f4d5eea31d51d53286e3673a1d9c34812507c9ef5f83eed
#   Stored in directory: /root/.cache/pip/wheels/b8/f3/19/6a938647065b4bb2471a9d063647d14d4fcc3236731f4e2b53
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x79a40706bee0>,
#  <randomuser.RandomUser at 0x79a40706abf0>,
#  <randomuser.RandomUser at 0x79a40706b310>,
#  <randomuser.RandomUser at 0x79a40706be20>,
#  <randomuser.RandomUser at 0x79a407069930>,
#  <randomuser.RandomUser at 0x79a40706b730>,
#  <randomuser.RandomUser at 0x79a40706b5b0>,
#  <randomuser.RandomUser at 0x79a40706bf10>,
#  <randomuser.RandomUser at 0x79a4070691b0>,
#  <randomuser.RandomUser at 0x79a40706af20>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Cohen Harris   cohen.harris@example.com
# Etiënne Smeulders   etienne.smeulders@example.com
# Nihal Polat   nihal.polat@example.com
# سارینا گلشن   sryn.glshn@example.com
# Ava Alme   ava.alme@example.com
# Zita Lemoine   zita.lemoine@example.com
# Lærke Christiansen   laerke.christiansen@example.com
# Toby Zhang   toby.zhang@example.com
# Alette Thunes   alette.thunes@example.com
# Latife Erberk   latife.erberk@example.com

# %% [markdown]
# ## Exercise 1
# In this Exercise, generate photos of the random 10 users.

# %%
from PIL import Image
import requests

photo=r.get_picture()
for user in some_list:
    print (user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/11.jpg
# https://randomuser.me/api/portraits/men/84.jpg
# https://randomuser.me/api/portraits/men/97.jpg
# https://randomuser.me/api/portraits/women/34.jpg
# https://randomuser.me/api/portraits/women/78.jpg
# https://randomuser.me/api/portraits/women/49.jpg
# https://randomuser.me/api/portraits/women/36.jpg
# https://randomuser.me/api/portraits/men/8.jpg
# https://randomuser.me/api/portraits/women/50.jpg
# https://randomuser.me/api/portraits/women/29.jpg

# %%
from PIL import Image
import requests
from io import BytesIO

# Assuming r.get_picture() retrieves a URL or a binary image
photo_url = r.get_picture()

# Function to get and show image from a URL
def show_image_from_url(url):
    response = requests.get(url)
    img = Image.open(BytesIO(response.content))
    display.display(img)

# Show the image from photo_url
show_image_from_url(photo_url)

# Assuming user.get_picture() retrieves a URL or a binary image
for user in some_list:
    user_photo_url = user.get_picture()
    print(user.get_picture())
    show_image_from_url(user_photo_url)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>
# https://randomuser.me/api/portraits/men/11.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>
# https://randomuser.me/api/portraits/men/84.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>
# https://randomuser.me/api/portraits/men/97.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>
# https://randomuser.me/api/portraits/women/34.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>
# https://randomuser.me/api/portraits/women/78.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>
# https://randomuser.me/api/portraits/women/49.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>
# https://randomuser.me/api/portraits/women/36.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>
# https://randomuser.me/api/portraits/men/8.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>
# https://randomuser.me/api/portraits/women/50.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=128x128>
# https://randomuser.me/api/portraits/women/29.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x128>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]

    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})

    return pd.DataFrame(users)

# %%
get_users()
# Out:
#              Name  Gender                   City               State  \
# 0    Kylie Fowler  female              Fairfield               Maine
# 1     Tina Oliver  female              Charlotte             Florida
# 2    Isaac Wilson    male             Upper Hutt         Hawke'S Bay
# 3      نیایش کوتی  female                    رشت      آذربایجان غربی
# 4  Chris Reinhold    male             Schneeberg  Schleswig-Holstein
# 5  Silke Pedersen  female               Ølstykke         Midtjylland
# 6   Jimi Moilanen    male                Utsjoki     Tavastia Proper
# 7    Petar Limmer    male  Schwarzenbach am Wald             Hamburg
# 8  Maurílio Viana    male          Montes Claros           Tocantins
# 9  Konsta Haataja    male                Keitele         Kymenlaakso
#
#                         Email                       DOB  \
# 0    kylie.fowler@example.com  1956-06-09T11:08:37.347Z
# 1     tina.oliver@example.com  1971-02-18T23:11:09.190Z
# 2    isaac.wilson@example.com  1989-03-28T23:53:12.354Z
# 3     nyysh.khwty@example.com  1949-08-13T12:58:13.790Z
# 4  chris.reinhold@example.com  1978-04-02T16:50:33.664Z
# 5  silke.pedersen@example.com  1986-03-01T17:47:59.665Z
# 6   jimi.moilanen@example.com  1954-09-16T16:10:32.081Z
# 7    petar.limmer@example.com  1971-03-30T23:26:37.690Z
# 8  maurilio.viana@example.com  1984-07-13T21:20:29.690Z
# 9  konsta.haataja@example.com  1985-09-14T01:20:53.039Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/36.jpg
# 1   https://randomuser.me/api/portraits/women/5.jpg
# 2    https://randomuser.me/api/portraits/men/14.jpg
# 3  https://randomuser.me/api/portraits/women/68.jpg
# 4     https://randomuser.me/api/portraits/men/5.jpg
# 5  https://randomuser.me/api/portraits/women/57.jpg
# 6    https://randomuser.me/api/portraits/men/48.jpg
# 7    https://randomuser.me/api/portraits/men/28.jpg
# 8    https://randomuser.me/api/portraits/men/28.jpg
# 9    https://randomuser.me/api/portraits/men/11.jpg

# %%
df1 = pd.DataFrame(get_users())
df1
# Out:
#                Name  Gender              City              State  \
# 0          Rose Lee  female           Dunedin         West Coast
# 1     بهاره نكو نظر  female             بوشهر           کرمانشاه
# 2    Sofia Sørensen  female      Aalborg S.Ø.         Syddanmark
# 3  Veronica Riviere  female        Feusisberg             Luzern
# 4       Sasha Wilke    male  Broekhuizenvorst          Flevoland
# 5   Livio Bourgeois    male          Le Havre           Morbihan
# 6        عباس جعفری    male             زنجان              بوشهر
# 7    Madalene Jesus  female           Birigüi           Rondônia
# 8   Josefine Jensen  female          Roedovre        Hovedstaden
# 9  Quinota da Cunha  female          Barretos  Rio Grande do Sul
#
#                           Email                       DOB  \
# 0          rose.lee@example.com  1979-12-27T19:01:13.136Z
# 1       bhrh.nkwnzr@example.com  1953-01-22T11:13:15.391Z
# 2    sofia.sorensen@example.com  1955-05-03T07:46:08.401Z
# 3  veronica.riviere@example.com  1994-10-18T21:43:44.085Z
# 4       sasha.wilke@example.com  1992-04-10T07:14:38.689Z
# 5   livio.bourgeois@example.com  1951-12-23T02:13:39.770Z
# 6       aabs.jaafry@example.com  1954-07-07T17:32:50.262Z
# 7    madalene.jesus@example.com  1981-07-26T04:47:20.376Z
# 8   josefine.jensen@example.com  1991-01-28T02:02:05.473Z
# 9   quinota.dacunha@example.com  1964-01-15T10:34:59.277Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/45.jpg
# 1  https://randomuser.me/api/portraits/women/80.jpg
# 2  https://randomuser.me/api/portraits/women/58.jpg
# 3  https://randomuser.me/api/portraits/women/80.jpg
# 4    https://randomuser.me/api/portraits/men/83.jpg
# 5    https://randomuser.me/api/portraits/men/47.jpg
# 6    https://randomuser.me/api/portraits/men/54.jpg
# 7  https://randomuser.me/api/portraits/women/28.jpg
# 8  https://randomuser.me/api/portraits/women/22.jpg
# 9  https://randomuser.me/api/portraits/women/50.jpg

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruityvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruityvice](https://www.fruityvice.com) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# 11                 Fig   68         Moraceae           Rosales         Ficus
# 12          Gooseberry   69  Grossulariaceae      Saxifragales         Ribes
# 13        Passionfruit   70   Passifloraceae      Malpighiales    Passiflora
# 14                Plum   71         Rosaceae           Rosales        Prunus
# 15              Orange    2         Rutaceae        Sapindales        Citrus
# 16          GreenApple   72         Rosaceae           Rosales         Malus
# 17           Raspberry   23         Rosaceae           Rosales         Rubus
# 18          Watermelon   25    Cucurbitaceae      Cucurbitales     Citrullus
# 19               Lemon   26         Rutaceae        Sapindales        Citrus
# 20               Mango   27    Anacardiaceae        Sapindales     Mangifera
# 21           Blueberry   33         Rosaceae           Rosales      Fragaria
# 22               Apple    6         Rosaceae           Rosales         Malus
# 23               Guava   37        Myrtaceae          Myrtales       Psidium
# 24             Apricot   35         Rosaceae           Rosales        Prunus
# 25               Melon   41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 26           Tangerine   77         Rutaceae        Sapindales        Citrus
# 27            Pitahaya   78        Cactaceae    Caryophyllales     Cactaceae
# 28                Lime   44         Rutaceae        Sapindales        Citrus
# 29         Pomegranate   79       Lythraceae          Myrtales        Punica
# 30         Dragonfruit   80        Cactaceae    Caryophyllales  Selenicereus
# 31               Grape   81         Vitaceae           Vitales         Vitis
# 32               Morus   82         Moraceae           Rosales         Morus
# 33              Feijoa   76        Myrtaceae        Myrtoideae    Sellowiana
# 34             Avocado   84        Lauraceae          Laurales        Persea
# 35           Kiwifruit   85    Actinidiaceae          Ericales     Actinidia
# 36           Cranberry   87        Ericaceae          Ericales     Vaccinium
# 37              Cherry    9         Rosaceae           Rosales        Prunus
# 38               Peach   86         Rosaceae           Rosales        Prunus
# 39           Jackfruit   94         Moraceae           Rosales    Artocarpus
# 40        Horned Melon   95    Cucurbitaceae      Cucurbitales       Cucumis
# 41            Hazelnut   96       Betulaceae           Fagales       Corylus
# 42              Pomelo   98         Rutaceae        Sapindales        Citrus
# 43          Mangosteen   99       Clusiaceae      Malpighiales      Garcinia
# 44             Pumpkin  100    Cucurbitaceae      Cucurbitales     Cucurbita
# 45  Japanese Persimmon  101        Ebenaceae          Ericales     Diospyros
# 46              Papaya   42       Caricaceae       Brassicales        Carica
# 47              Annona  103       Annonaceae           Rosales       Annonas
# 48   Ceylon Gooseberry  104       Salicaceae      Malpighiales      Dovyalis
#
#                                            nutritions
# 0   {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1   {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2   {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3   {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4   {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...
# 5   {'calories': 147, 'fat': 5.3, 'sugar': 6.75, '...
# 6   {'calories': 40, 'fat': 0.4, 'sugar': 4.5, 'ca...
# 7   {'calories': 50, 'fat': 0.34, 'sugar': 5.74, '...
# 8   {'calories': 61, 'fat': 0.5, 'sugar': 9.0, 'ca...
# 9   {'calories': 66, 'fat': 0.44, 'sugar': 15.0, '...
# 10  {'calories': 50, 'fat': 0.12, 'sugar': 9.85, '...
# 11  {'calories': 74, 'fat': 0.3, 'sugar': 16.0, 'c...
# 12  {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'ca...
# 13  {'calories': 97, 'fat': 0.7, 'sugar': 11.2, 'c...
# 14  {'calories': 46, 'fat': 0.28, 'sugar': 9.92, '...
# 15  {'calories': 43, 'fat': 0.2, 'sugar': 8.2, 'ca...
# 16  {'calories': 21, 'fat': 0.1, 'sugar': 6.4, 'ca...
# 17  {'calories': 53, 'fat': 0.7, 'sugar': 4.4, 'ca...
# 18  {'calories': 30, 'fat': 0.2, 'sugar': 6.0, 'ca...
# 19  {'calories': 29, 'fat': 0.3, 'sugar': 2.5, 'ca...
# 20  {'calories': 60, 'fat': 0.38, 'sugar': 13.7, '...
# 21  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 22  {'calories': 52, 'fat': 0.4, 'sugar': 10.3, 'c...
# 23  {'calories': 68, 'fat': 1.0, 'sugar': 9.0, 'ca...
# 24  {'calories': 15, 'fat': 0.1, 'sugar': 3.2, 'ca...
# 25  {'calories': 34, 'fat': 0.0, 'sugar': 8.0, 'ca...
# 26  {'calories': 45, 'fat': 0.4, 'sugar': 9.1, 'ca...
# 27  {'calories': 36, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 28  {'calories': 25, 'fat': 0.1, 'sugar': 1.7, 'ca...
# 29  {'calories': 83, 'fat': 1.2, 'sugar': 13.7, 'c...
# 30  {'calories': 60, 'fat': 1.5, 'sugar': 8.0, 'ca...
# 31  {'calories': 69, 'fat': 0.16, 'sugar': 16.0, '...
# 32  {'calories': 43, 'fat': 0.39, 'sugar': 8.1, 'c...
# 33  {'calories': 44, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 34  {'calories': 160, 'fat': 14.66, 'sugar': 0.66,...
# 35  {'calories': 61, 'fat': 0.5, 'sugar': 8.9, 'ca...
# 36  {'calories': 46, 'fat': 0.1, 'sugar': 4.0, 'ca...
# 37  {'calories': 50, 'fat': 0.3, 'sugar': 8.0, 'ca...
# 38  {'calories': 39, 'fat': 0.25, 'sugar': 8.4, 'c...
# 39  {'calories': 95, 'fat': 0.0, 'sugar': 19.1, 'c...
# 40  {'calories': 44, 'fat': 1.26, 'sugar': 0.5, 'c...
# 41  {'calories': 628, 'fat': 61.0, 'sugar': 4.3, '...
# 42  {'calories': 37, 'fat': 0.0, 'sugar': 8.5, 'ca...
# 43  {'calories': 73, 'fat': 0.58, 'sugar': 16.11, ...
# 44  {'calories': 25, 'fat': 0.3, 'sugar': 3.3, 'ca...
# 45  {'calories': 70, 'fat': 0.2, 'sugar': 13.0, 'c...
# 46  {'calories': 39, 'fat': 0.3, 'sugar': 4.4, 'ca...
# 47  {'calories': 92, 'fat': 0.29, 'sugar': 3.4, 'c...
# 48  {'calories': 47, 'fat': 0.3, 'sugar': 8.1, 'ca...

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# 11                 Fig   68         Moraceae           Rosales         Ficus
# 12          Gooseberry   69  Grossulariaceae      Saxifragales         Ribes
# 13        Passionfruit   70   Passifloraceae      Malpighiales    Passiflora
# 14                Plum   71         Rosaceae           Rosales        Prunus
# 15              Orange    2         Rutaceae        Sapindales        Citrus
# 16          GreenApple   72         Rosaceae           Rosales         Malus
# 17           Raspberry   23         Rosaceae           Rosales         Rubus
# 18          Watermelon   25    Cucurbitaceae      Cucurbitales     Citrullus
# 19               Lemon   26         Rutaceae        Sapindales        Citrus
# 20               Mango   27    Anacardiaceae        Sapindales     Mangifera
# 21           Blueberry   33         Rosaceae           Rosales      Fragaria
# 22               Apple    6         Rosaceae           Rosales         Malus
# 23               Guava   37        Myrtaceae          Myrtales       Psidium
# 24             Apricot   35         Rosaceae           Rosales        Prunus
# 25               Melon   41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 26           Tangerine   77         Rutaceae        Sapindales        Citrus
# 27            Pitahaya   78        Cactaceae    Caryophyllales     Cactaceae
# 28                Lime   44         Rutaceae        Sapindales        Citrus
# 29         Pomegranate   79       Lythraceae          Myrtales        Punica
# 30         Dragonfruit   80        Cactaceae    Caryophyllales  Selenicereus
# 31               Grape   81         Vitaceae           Vitales         Vitis
# 32               Morus   82         Moraceae           Rosales         Morus
# 33              Feijoa   76        Myrtaceae        Myrtoideae    Sellowiana
# 34             Avocado   84        Lauraceae          Laurales        Persea
# 35           Kiwifruit   85    Actinidiaceae          Ericales     Actinidia
# 36           Cranberry   87        Ericaceae          Ericales     Vaccinium
# 37              Cherry    9         Rosaceae           Rosales        Prunus
# 38               Peach   86         Rosaceae           Rosales        Prunus
# 39           Jackfruit   94         Moraceae           Rosales    Artocarpus
# 40        Horned Melon   95    Cucurbitaceae      Cucurbitales       Cucumis
# 41            Hazelnut   96       Betulaceae           Fagales       Corylus
# 42              Pomelo   98         Rutaceae        Sapindales        Citrus
# 43          Mangosteen   99       Clusiaceae      Malpighiales      Garcinia
# 44             Pumpkin  100    Cucurbitaceae      Cucurbitales     Cucurbita
# 45  Japanese Persimmon  101        Ebenaceae          Ericales     Diospyros
# 46              Papaya   42       Caricaceae       Brassicales        Carica
# 47              Annona  103       Annonaceae           Rosales       Annonas
# 48   Ceylon Gooseberry  104       Salicaceae      Malpighiales      Dovyalis
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 0                    81            0.00             18.00
# 1                    29            0.40              5.40
# 2                    96            0.20             17.20
# 3                    74            0.20              2.60
# 4                    57            0.10             10.00
# 5                   147            5.30              6.75
# 6                    40            0.40              4.50
# 7                    50            0.34              5.74
# 8                    61            0.50              9.00
# 9                    66            0.44             15.00
# 10                   50            0.12              9.85
# 11                   74            0.30             16.00
# 12                   44            0.60              0.00
# 13                   97            0.70             11.20
# 14                   46            0.28              9.92
# 15                   43            0.20              8.20
# 16                   21            0.10              6.40
# 17                   53            0.70              4.40
# 18                   30            0.20              6.00
# 19                   29            0.30              2.50
# 20                   60            0.38             13.70
# 21                   29            0.40              5.40
# 22                   52            0.40             10.30
# 23                   68            1.00              9.00
# 24                   15            0.10              3.20
# 25                   34            0.00              8.00
# 26                   45            0.40              9.10
# 27                   36            0.40              3.00
# 28                   25            0.10              1.70
# 29                   83            1.20             13.70
# 30                   60            1.50              8.00
# 31                   69            0.16             16.00
# 32                   43            0.39              8.10
# 33                   44            0.40              3.00
# 34                  160           14.66              0.66
# 35                   61            0.50              8.90
# 36                   46            0.10              4.00
# 37                   50            0.30              8.00
# 38                   39            0.25              8.40
# 39                   95            0.00             19.10
# 40                   44            1.26              0.50
# 41                  628           61.00              4.30
# 42                   37            0.00              8.50
# 43                   73            0.58             16.11
# 44                   25            0.30              3.30
# 45                   70            0.20             13.00
# 46                   39            0.30              4.40
# 47                   92            0.29              3.40
# 48                   47            0.30              8.10
#
#     nutritions.carbohydrates  nutritions.protein
# 0                      18.00                0.00
# 1                       5.50                0.80
# 2                      22.00                1.00
# 3                       3.90                0.90
# 4                      15.00                0.40
# 5                      27.10                1.50
# 6                       9.00                1.30
# 7                      11.30                0.75
# 8                      15.00                1.10
# 9                      17.00                0.80
# 10                     13.12                0.54
# 11                     19.00                0.80
# 12                     10.00                0.90
# 13                     22.40                2.20
# 14                     11.40                0.70
# 15                      8.30                1.00
# 16                      3.10                0.40
# 17                     12.00                1.20
# 18                      8.00                0.60
# 19                      9.00                1.10
# 20                     15.00                0.82
# 21                      5.50                0.00
# 22                     11.40                0.30
# 23                     14.00                2.60
# 24                      3.90                0.50
# 25                      8.00                0.00
# 26                      8.30                0.00
# 27                      7.00                1.00
# 28                      8.40                0.30
# 29                     18.70                1.70
# 30                      9.00                9.00
# 31                     18.10                0.72
# 32                      9.80                1.44
# 33                      8.00                0.60
# 34                      8.53                2.00
# 35                     14.60                1.14
# 36                     12.20                0.40
# 37                     12.00                1.00
# 38                      9.50                0.90
# 39                     23.20                1.72
# 40                      7.56                1.78
# 41                     17.00               15.00
# 42                      9.67                0.82
# 43                     17.91                0.41
# 44                      4.60                1.10
# 45                     19.00                0.60
# 46                      5.80                0.50
# 47                     19.10                1.50
# 48                      9.60                1.20

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
# In this Exercise, find out how many calories are contained in a banana.

# %%
Banana = df2.loc[df2["name"] == 'Banana']
print('Number of calories of: ',Banana.iloc[0]['name'],(Banana.iloc[0]['nutritions.calories']))
# Out:
# Number of calories of:  Banana 96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://mixedanalytics.com/blog/list-actually-free-open-no-auth-needed-apis/) contains a list of free public APIs for you to practice. Let us deal with the following example.
#
# #### Official Joke API
# This API returns random jokes from a database. The following URL can be used to retrieve 10 random jokes.
#
# https://official-joke-api.appspot.com/jokes/ten
#
# 1. Using `requests.get("url")` function, load the data from the URL.

# %%
import requests
import json

data2=requests.get('https://official-joke-api.appspot.com/jokes/ten')

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://official-joke-api.appspot.com/jokes/ten")
# ```
#
# </details>

# %% [markdown]
# 2. Retrieve results using `json.loads()` function.

# %%
joke = json.loads(data2.text)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3. Convert json data into *pandas* data frame. Drop the type and id columns.

# %%
df2=pd.DataFrame(joke)
#df2.drop(['type','id'], axis=1, inplace=True)
# alternatively
df2.drop(columns=['type','id'], inplace=True)
df2
# Out:
#                                                setup  \
# 0      What is a witch's favorite subject in school?
# 1                Why did the rooster cross the road?
# 2    How did the hipster burn the roof of his mouth?
# 3  What did the big flower say to the littler flo...
# 4                                   Why do bees hum?
# 5       Why couldn't the bicycle stand up by itself?
# 6             What did the dog say to the two trees?
# 7             I can't tell if i like this blender...
# 8              Where do programmers like to hangout?
# 9           What do you call an alligator in a vest?
#
#                                            punchline
# 0                                          Spelling!
# 1  He heard that the chickens at KFC were pretty ...
# 2               He ate the pizza before it was cool.
# 3                                           Hi, bud!
# 4                 Because they don't know the words.
# 5                                  It was two-tired.
# 6                                         Bark bark.
# 7                  It keeps giving me mixed results.
# 8                                       The Foo Bar.
# 9                                 An in-vest-igator!

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3.drop(columns=["type","id"],inplace=True)
# df3
# ```
#
# </details>

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
# <a href="https://www.linkedin.com/in/svitlana-kramar" target="_blank">Svitlana Kramar</a>
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.
#
# ## Additional Contributor
# <a href="https://www.linkedin.com/in/abhishek-gagneja-23051987/" target="_blank">Abhishek Gagneja</a>

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.

# %% [markdown]
# ## An example of plotting bitcoin price in Python
# Source: https://medium.com/analytics-vidhya/plotting-bitcoin-candlestick-using-python-5a307e02d30

# %%
pip install pandas pandas_datareader
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: pandas_datareader in /usr/local/lib/python3.10/dist-packages (0.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from pandas_datareader) (4.9.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pandas_datareader) (2.31.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pandas_datareader) (2024.7.4)

# %%
pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.40)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.25.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.6)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.7.4)

# %%
# Import the libraries
import pandas as pd
import pandas_datareader.data as pdr
import datetime
import yfinance as yf # I added y finance because Yahoo (from the source) did not work for me

# %%
# Provide the range of dates from which you want to retrieve bitcoin price (yy-mm-dd)
start = datetime.datetime(2024,1,1)
end = datetime.datetime(2024,7,10) # i modified also this line as it was not correct in the source
# create a dataframe
df = yf.download('BTC-USD', start=start, end=end)
# check the values obtained and the Dataframe structure
df.head()
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                     Open          High           Low         Close  \
# Date
# 2024-01-01  42280.234375  44175.437500  42214.976562  44167.332031
# 2024-01-02  44187.140625  45899.707031  44176.949219  44957.968750
# 2024-01-03  44961.601562  45503.242188  40813.535156  42848.175781
# 2024-01-04  42855.816406  44770.023438  42675.175781  44179.921875
# 2024-01-05  44192.980469  44353.285156  42784.718750  44162.691406
#
#                Adj Close       Volume
# Date
# 2024-01-01  44167.332031  18426978443
# 2024-01-02  44957.968750  39335274536
# 2024-01-03  42848.175781  46342323118
# 2024-01-04  44179.921875  30448091210
# 2024-01-05  44162.691406  32336029347

# %%
# Import the libraries to use plotly and create an interactive graph
import plotly.offline as py
import plotly.graph_objs as go
import plotly.io as pio

# %%
# This line is to render the plot inside the notebook
py.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# for the desired type of plot it was selected candlestick type
# x for the date and the y axis fields are open price, high, low and close value
data = [go.Candlestick(x=df.index,
                       open=df.Open,
                       high=df.High,
                       low=df.Low,
                       close=df.Close)]

# %%
# This layout is the same as the source which add selectors to the plot, so it can plot the BTC price in a month, year, day ..
layout = go.Layout(title='Bitcoin Candlestick with Range Slider and Selectors',
                  xaxis={'rangeselector':{'buttons':[{'count':7,
                                                      'label':'1w',
                                                      'step':'day',
                                                      'stepmode':'backward'},
                                                     {'count':1,
                                                      'label':'1m',
                                                      'step':'month',
                                                      'stepmode':'backward'},
                                                    {'count':3,
                                                      'label':'3m',
                                                      'step':'month',
                                                      'stepmode':'backward'},
                                                    {'count':6,
                                                      'label':'6m',
                                                      'step':'month',
                                                      'stepmode':'backward'},
                                                    {'count':1,
                                                      'label':'1y',
                                                      'step':'year',
                                                      'stepmode':'backward'},
                                                      ]
                          },
                         'rangeslider':{'visible':True}})

# %%
# This line allows rendering the plot in colab: https://stackoverflow.com/questions/47230817/plotly-notebook-mode-with-google-colaboratory
pio.renderers.default = "colab"
fig = go.Figure(data=data,layout=layout)
py.iplot(fig,filename='bitcoin_candlestick')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="928f8004-4e6e-47d2-b49c-b8bed76efbb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("928f8004-4e6e-47d2-b49c-b8bed76efbb8")) {                    Plotly.newPlot(                        "928f8004-4e6e-47d2-b49c-b8bed76efbb8",                        [{"close":[44167.33203125,44957.96875,42848.17578125,44179.921875,44162.69140625,43989.1953125,43943.09765625,46970.50390625,46139.73046875,46627.77734375,46368.5859375,42853.16796875,42842.3828125,41796.26953125,42511.96875,43154.9453125,42742.65234375,41262.05859375,41618.40625,41665.5859375,41545.78515625,39507.3671875,39845.55078125,40077.07421875,39933.80859375,41816.87109375,42120.0546875,42035.59375,43288.24609375,42952.609375,42582.60546875,43075.7734375,43185.859375,42992.25,42583.58203125,42658.66796875,43084.671875,44318.22265625,45301.56640625,47147.19921875,47771.27734375,48293.91796875,49958.22265625,49742.44140625,51826.6953125,51938.5546875,52160.203125,51662.99609375,52122.546875,51779.14453125,52284.875,51839.1796875,51304.97265625,50731.94921875,51571.1015625,51733.23828125,54522.40234375,57085.37109375,62504.7890625,61198.3828125,62440.6328125,62029.84765625,63167.37109375,68330.4140625,63801.19921875,66106.8046875,66925.484375,68300.09375,68498.8828125,69019.7890625,72123.90625,71481.2890625,73083.5,71396.59375,69403.7734375,65315.1171875,68390.625,67548.59375,61912.7734375,67913.671875,65491.390625,63778.76171875,64062.203125,67234.171875,69958.8125,69987.8359375,69455.34375,70744.953125,69892.828125,69645.3046875,71333.6484375,69702.1484375,65446.97265625,65980.8125,68508.84375,67837.640625,68896.109375,69362.5546875,71631.359375,69139.015625,70587.8828125,70060.609375,67195.8671875,63821.47265625,65738.7265625,63426.2109375,63811.86328125,61276.69140625,63512.75390625,63843.5703125,64994.44140625,64926.64453125,66837.6796875,66407.2734375,64276.8984375,64481.70703125,63755.3203125,63419.140625,63113.23046875,63841.12109375,60636.85546875,58254.01171875,59123.43359375,62889.8359375,63891.47265625,64031.1328125,63161.94921875,62334.81640625,61187.94140625,63049.9609375,60792.77734375,60793.7109375,61448.39453125,62901.44921875,61552.7890625,66267.4921875,65231.58203125,67051.875,66940.8046875,66278.3671875,71448.1953125,70136.53125,69122.3359375,67929.5625,68526.1015625,69265.9453125,68518.09375,69394.5546875,68296.21875,67578.09375,68364.9921875,67491.4140625,67706.9375,67751.6015625,68804.78125,70567.765625,71082.8203125,70757.1640625,69342.5859375,69305.7734375,69647.9921875,69512.28125,67332.03125,68241.1875,66756.3984375,66011.09375,66191.0,66639.046875,66490.296875,65140.74609375,64960.296875,64828.65625,64096.19921875,64252.578125,63180.796875,60277.4140625,61804.640625,60811.27734375,61604.80078125,60320.13671875,60887.37890625,62678.29296875,62851.98046875,62029.015625,60173.921875,56977.703125,56662.375,58303.5390625,55849.109375,56705.09765625,58009.2265625],"high":[44175.4375,45899.70703125,45503.2421875,44770.0234375,44353.28515625,44227.6328125,44495.5703125,47218.0,47893.69921875,47647.22265625,48969.37109375,46498.13671875,43234.66015625,43065.59765625,43319.72265625,43566.2734375,43189.890625,42876.34765625,42134.16015625,41877.89453125,41855.3671875,41651.20703125,40127.3515625,40483.78515625,40254.48046875,42209.38671875,42195.6328125,42797.17578125,43305.8671875,43838.9453125,43717.40625,43243.16796875,43422.48828125,43359.94140625,43097.64453125,43494.25,43344.1484375,44341.94921875,45575.83984375,48152.49609375,48146.171875,48535.9375,50280.4765625,50358.390625,52021.37109375,52820.06640625,52537.96875,52191.9140625,52356.96484375,52483.32421875,52945.05078125,52368.81640625,52009.61328125,51497.93359375,51684.1953125,51950.0273437 ...
